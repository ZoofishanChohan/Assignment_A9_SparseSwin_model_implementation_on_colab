# %% [markdown]
# <a href="https://colab.research.google.com/github/ZoofishanChohan/Assignment_A9_SparseSwin_model_implementation_on_colab/blob/main/Swin_Transformer_only_A9_cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Aug  5 17:33:22 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   48C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import psutil

ram_gb = psutil.virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 56.9 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# !git clone https://github.com/KrisnaPinasthika/SparseSwin.git
# %cd SparseSwin
# Out:
# Cloning into 'SparseSwin'...
# remote: Enumerating objects: 657, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 657 (delta 14), reused 54 (delta 11), pack-reused 596 (from 1)
# Receiving objects: 100% (657/657), 1.11 GiB | 46.07 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# Updating files: 100% (548/548), done.
# /content/SparseSwin

# %%
from torchvision import datasets
datasets.CIFAR10(root='./data', train=True, download=True)
datasets.CIFAR100(root='./data', train=True, download=True)
# Out:
# 100%|██████████| 170M/170M [00:03<00:00, 43.6MB/s]
# 100%|██████████| 169M/169M [00:03<00:00, 43.5MB/s]
# Dataset CIFAR100
#     Number of datapoints: 50000
#     Root location: ./data
#     Split: Train

# %%
# !python train_cifar.py --config configs/sparse_cifar10.yaml --save_dir results/cifar10
# Out:
# Downloading: "https://download.pytorch.org/models/swin_t-704ceda3.pth" to /root/.cache/torch/hub/checkpoints/swin_t-704ceda3.pth
# 100% 108M/108M [00:00<00:00, 197MB/s]
# [TRAIN] Total : 4167 | type : tiny | Regularization : None with lamda : 0.0
# Epoch 1/20
#   [200/4167] Loss: 1.8281 Acc : 0.3375
#   [400/4167] Loss: 1.4544 Acc : 0.4854
#   [600/4167] Loss: 1.2714 Acc : 0.5543
#   [800/4167] Loss: 1.1579 Acc : 0.5957
#   [1000/4167] Loss: 1.0890 Acc : 0.6224
#   [1200/4167] Loss: 1.0441 Acc : 0.6368
#   [1400/4167] Loss: 0.9933 Acc : 0.6544
#   [1600/4167] Loss: 0.9640 Acc : 0.6640
#   [1800/4167] Loss: 0.9365 Acc : 0.6735
#   [2000/4167] Loss: 0.9082 Acc : 0.6837
#   [2200/4167] Loss: 0.8880 Acc : 0.6902
#   [2400/4167] Loss: 0.8729 Acc : 0.6958
#   [2600/4167] Loss: 0.8559 Acc : 0.7014
#   [2800/4167] Loss: 0.8409 Acc : 0.7065
#   [3000/4167] Loss: 0.8279 Acc : 0.7109
#   [3200/4167] Loss: 0.8165 Acc : 0.7150
#   [3400/4167] Loss: 0.8060 Acc : 0.7192
# ...
