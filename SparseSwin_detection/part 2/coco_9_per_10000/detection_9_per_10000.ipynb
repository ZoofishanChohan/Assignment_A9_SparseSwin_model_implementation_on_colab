# %%
# %cd /content
# !git clone https://github.com/KrisnaPinasthika/SparseSwin.git
# %cd SparseSwin/SparseSwinDet
# Out:
# /content
# Cloning into 'SparseSwin'...
# remote: Enumerating objects: 657, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 657 (delta 14), reused 54 (delta 11), pack-reused 596 (from 1)
# Receiving objects: 100% (657/657), 1.11 GiB | 16.85 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# Updating files: 100% (548/548), done.
# /content/SparseSwin/SparseSwinDet

# %%
# !pip install -r requirements.txt

# %%
# !pip install torchprofile

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
import random

# Add this to keep the session active
while True:
    print(f"Keeping session alive: {time.strftime('%Y-%m-%d %H:%M:%S')}")
    time.sleep(300)  # Print every 5 minutes
    # Add some random computation to show activity
    dummy = sum([random.randint(1,100) for _ in range(1000)])

# %%
# !python train.py \
--data_path /content/drive/MyDrive/coco_subset_9_per/ \
--sparseswin_type tiny  \
--num_epochs 10 \
--log_path /content/drive/MyDrive/coco_9_per_training/logs \
--saved_path /content/drive/MyDrive/coco_9_per_training/trainedparams
# Out:
# loading annotations into memory...
# Done (t=2.83s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.77s)
# creating index...
# index created!
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch: 1/10. Iteration: 1250/1250. Cls loss: 0.55156. Reg loss: 0.59535. Batch loss: 1.14691 Total loss: 1.58345: 100% 1250/1250 [54:09<00:00,  2.60s/it]
# Epoch: 1/10. Classification loss: 0.56025. Regression loss: 0.70949. Total loss: 1.26974
# Epoch: 2/10. Iteration: 1250/1250. Cls loss: 0.54495. Reg loss: 0.62240. Batch loss: 1.16734 Total loss: 1.21095: 100% 1250/1250 [11:56<00:00,  1.74it/s]
# Epoch: 2/10. Classification loss: 0.47089. Regression loss: 0.62459. Total loss: 1.09548
# Epoch: 3/10. Iteration: 1250/1250. Cls loss: 0.50502. Reg loss: 0.44922. Batch loss: 0.95423 Total loss: 1.05378: 100% 1250/1250 [12:00<00:00,  1.74it/s]
# Epoch: 3/10. Classification loss: 0.47135. Regression loss: 0.59025. Total loss: 1.06161
# Epoch: 4/10. Iteration: 1250/1250. Cls loss: 0.39434. Reg loss: 0.62989. Batch loss: 1.02423 Total loss: 0.95363: 100% 1250/1250 [12:00<00:00,  1.74it/s]
# Epoch: 4/10. Classification loss: 0.38807. Regression loss: 0.57437. Total loss: 0.96244
# Epoch: 5/10. Iteration: 1250/1250. Cls loss: 0.36244. Reg loss: 0.56149. Batch loss: 0.92393 Total loss: 0.87212: 100% 1250/1250 [11:58<00:00,  1.74it/s]
# Epoch: 5/10. Classification loss: 0.36865. Regression loss: 0.54554. Total loss: 0.91419
# Epoch: 6/10. Iteration: 1250/1250. Cls loss: 0.32085. Reg loss: 0.62007. Batch loss: 0.94092 Total loss: 0.81197: 100% 1250/1250 [12:00<00:00,  1.74it/s]
# Epoch: 6/10. Classification loss: 0.34944. Regression loss: 0.53607. Total loss: 0.88551
# Epoch: 7/10. Iteration: 1250/1250. Cls loss: 0.22867. Reg loss: 0.41198. Batch loss: 0.64064 Total loss: 0.76433: 100% 1250/1250 [12:01<00:00,  1.73it/s]
# Epoch: 7/10. Classification loss: 0.35083. Regression loss: 0.52783. Total loss: 0.87866
# Epoch: 8/10. Iteration: 1250/1250. Cls loss: 0.22740. Reg loss: 0.50996. Batch loss: 0.73737 Total loss: 0.71378: 100% 1250/1250 [12:00<00:00,  1.73it/s]
# Epoch: 8/10. Classification loss: 0.36159. Regression loss: 0.52321. Total loss: 0.88480
# Epoch: 9/10. Iteration: 1250/1250. Cls loss: 0.22908. Reg loss: 0.46571. Batch loss: 0.69479 Total loss: 0.67516: 100% 1250/1250 [11:59<00:00,  1.74it/s]
# Epoch: 9/10. Classification loss: 0.36841. Regression loss: 0.52806. Total loss: 0.89647
# Epoch: 10/10. Iteration: 1250/1250. Cls loss: 0.24716. Reg loss: 0.44517. Batch loss: 0.69233 Total loss: 0.64318: 100% 1250/1250 [12:05<00:00,  1.72it/s]
# Epoch: 10/10. Classification loss: 0.34713. Regression loss: 0.51946. Total loss: 0.86659

# %%
# !python mAP_evaluation.py
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.18s).
# Accumulating evaluation results...
# DONE (t=0.04s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.129
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.269
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.102
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.054
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.235
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.298
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.193
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.374
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.428

# %%
# !python mAP_evaluation.py
# Out:
# 3
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.normalization.LayerNorm'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register count_upsample() for <class 'torch.nn.modules.upsampling.Upsample'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# GFLOPs: 115.71, Params: 32623781.00
